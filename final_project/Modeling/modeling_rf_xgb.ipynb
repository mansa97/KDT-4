# %% [markdown]
# ---
# ### 사용자 지정함수
# ---

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
# RandomForest
from sklearn.ensemble import RandomForestRegressor
def modeling_rf(train_x, train_y, test_x, test_y):
    model=RandomForestRegressor()
    model.fit(train_x,train_y)
    train_score=model.score(train_x,train_y)
    test_score = model.score(test_x,test_y)
    pred = model.predict(test_x)
    plt.plot(test_y.reset_index(drop=True), label='실제값')
    plt.plot(pred,label='예측값')
    plt.legend()
    plt.show()
    print(f'train score : {train_score}, test score : {test_score}')
    mse = mean_squared_error(test_y, pred)
    rmse = mse ** 0.5
    print(rmse)

# XGBoost
from xgboost import XGBRegressor
def modeling_xgb(train_x, train_y, test_x, test_y):
    model=XGBRegressor()
    model.fit(train_x, train_y)
    train_score=model.score(train_x,train_y)
    test_score = model.score(test_x,test_y)
    pred = model.predict(test_x)
    plt.plot(test_y.reset_index(drop=True), label='실제값')
    plt.plot(pred,label='예측값')
    plt.legend()
    plt.show()
    print(f'train score : {train_score}, test score : {test_score}')
    mse = mean_squared_error(test_y, pred)
    rmse = mse ** 0.5
    print(rmse)

def modeling_all(train_x, train_y, test_x, test_y, filename):
    # RandomForest
    from sklearn.ensemble import RandomForestRegressor
    model=RandomForestRegressor()
    model.fit(train_x,train_y)
    train_score_rf=model.score(train_x,train_y)
    test_score_rf = model.score(test_x,test_y)
    pred = model.predict(test_x)
    if test_score_rf > 0:
        print(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}')
        mse = mean_squared_error(test_y, pred)
        rmse = mse ** 0.5
        print(f'** rmse : {rmse}')
        with open(f'./1204_1208/modeling_result/{filename}.txt', 'a') as file_data:
            file_data.write(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}\n')
            file_data.write(f'** rmse : {rmse}\n')
    # XGBoost
    from xgboost import XGBRegressor
    model=XGBRegressor()
    model.fit(train_x,train_y)
    train_score_xgb = model.score(train_x,train_y)
    test_score_xgb = model.score(test_x,test_y)
    pred = model.predict(test_x)
    if test_score_xgb > 0:
        print(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}')
        mse = mean_squared_error(test_y, pred)
        rmse = mse ** 0.5
        print(f'** rmse : {rmse}')
        with open('./1204_1208/modeling_result/rf_xgb_result.txt', 'a') as file_data:
            file_data.write(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}\n')
            file_data.write(f'** rmse : {rmse}\n')
    if (test_score_rf > 0) | (test_score_xgb > 0):
        print(f'독립변수 : {train_x.columns}')
        print('-'*100)
        with open('./1204_1208/modeling_result/rf_xgb_result.txt', 'a') as file_data:
            file_data.write(f'독립변수 : {train_x.columns}\n')
            file_data.write('-'*100+'\n')
    

# Min_Max_Scaler
from sklearn.preprocessing import MinMaxScaler
def mms(all_df):
    scaler = MinMaxScaler()
    for i in all_df.columns:
        if i!='날짜' and i!='선반A (Turning Scrap A) 평균':
            all_df[i]=scaler.fit_transform(all_df[[i]])
    return all_df

# 결과(차트, rmse)
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
def make_chart(pred, test_y):
    mse = mean_squared_error(test_y, pred)
    rmse = mse ** 0.5
    # print(rmse)
    plt.figure(figsize=(11,6))
    plt.plot(pred,label='예측값')
    plt.plot(test_y.values,label='실제값')
    plt.legend()

# %% [markdown]
# ---
# #### 1. 데이터 불러오기
# ---

# %%
#----------------------------------------------------
# 데이터 불러오기
import pandas as pd
all_df = pd.read_csv('./data/tsa_all.csv')
#----------------------------------------------------
# MinMaxScaling
from sklearn.preprocessing import MinMaxScaler
all_df=mms(all_df)
#----------------------------------------------------

# %% [markdown]
# ---
# #### 2. 시각화
# ---

# %%
import matplotlib.pyplot as plt
cnt=0
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(20,20))
for i in all_df.columns[2:len(all_df.columns)]:
    cnt+=1
    plt.subplot(5,4,cnt)
    plt.rc('font', family='Malgun Gothic')
    plt.plot(all_df[i],label=i) 
    scaler = MinMaxScaler()
    plt.plot(scaler.fit_transform(all_df[['선반A (Turning Scrap A) 평균']]),label='선반A') 
    plt.legend(loc=1)
    plt.xlabel(i)

# %%
# 상관계수
df_corr=all_df.iloc[:,1:].corr()['선반A (Turning Scrap A) 평균'].iloc[1:].to_frame()
df_corr
# Out:
#                  선반A (Turning Scrap A) 평균
# 달러 환율                            0.168338
# 엔 환율                             0.121042
# 유로 환율                            0.206238
# 위안 환율                            0.271835
# 금속광물 수입금액                        0.654380
# 철광석 수입금액                         0.569439
# 금속광물 수입물량                        0.231210
# 철광석 수입물량                         0.202000
# 무역수지                            -0.487305
# 철광석 가격                           0.474755
# G20                              0.091011
# 한국                              -0.144263
# 미국                               0.157608
# 중국                              -0.095003
# 수입물가지수                           0.492782
# 국제유가(Dubai, 좌축)                  0.684361
# 금(우축)                            0.509773

# %%
# corr 0.45 이상인 컬럼 추출
best_index=df_corr[(abs(df_corr['선반A (Turning Scrap A) 평균'])>0.45)&(df_corr['선반A (Turning Scrap A) 평균']!=1)].index
print(best_index)
# Out:
# Index(['금속광물 수입금액', '철광석 수입금액', '무역수지', '철광석 가격', '수입물가지수', '국제유가(Dubai, 좌축)',
#        '금(우축)'],
#       dtype='object')

# %% [markdown]
# ---
# #### 3. 독립변수, 종속변수 분리
# ---

# %%
feature=all_df[best_index]
target=all_df.iloc[:]['선반A (Turning Scrap A) 평균']

# %% [markdown]
# ---
# #### 4. 모델링
# ---

# %%
# 스케일링 적용, 상관계수가 0.45 이상인 항목들 적용
import pandas as pd
from itertools import combinations
filename='best_corr_rf_xgb_result'

print('-'*100)
with open(f'./1204_1208/modeling_result/{filename}.txt', 'w') as file_data:
            file_data.write('-'*100+'\n')


# 조합을 이용하여 모든 경우의 수 계산
for cnt in range(1,len(best_index)+1):
    for i in combinations(best_index,cnt):
        feature=all_df[list(i)]
        target=all_df.iloc[:]['선반A (Turning Scrap A) 평균']
        # train, test 분리
        train_x=feature.iloc[:round(len(feature)*0.8),:]
        test_x=feature.iloc[round(len(feature)*0.8):,:]
        train_y=target.iloc[:round(len(feature)*0.8)]
        test_y=target.iloc[round(len(feature)*0.8):]
        # print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
        modeling_all(train_x, train_y, test_x, test_y,filename)
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8523, test score : 0.1421
# ** rmse : 104.67596472338967
# XGBoost => train score : 0.3392, test score : 0.2164
# ** rmse : 100.0403960336654
# 독립변수 : Index(['금속광물 수입금액'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8574, test score : 0.0165
# ** rmse : 112.07595173291236
# XGBoost => train score : 0.3878, test score : 0.0508
# ** rmse : 110.10253232891768
# 독립변수 : Index(['금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9318, test score : 0.0885
# ** rmse : 107.8909458640462
# XGBoost => train score : 0.8355, test score : 0.1197
# ** rmse : 106.03052140213839
# 독립변수 : Index(['금속광물 수입금액', '철광석 수입금액'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9696, test score : 0.1296
# ** rmse : 105.43426789001194
# 독립변수 : Index(['금속광물 수입금액', '무역수지'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9872, test score : 0.1518
# ** rmse : 104.07731865021753
# XGBoost => train score : 0.9689, test score : 0.1273
# ** rmse : 105.57480240147683
# 독립변수 : Index(['금속광물 수입금액', '철광석 가격'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9794, test score : 0.1467
# ** rmse : 104.3920138029877
# XGBoost => train score : 0.9557, test score : 0.1290
# ** rmse : 105.4680434299281
# 독립변수 : Index(['금속광물 수입금액', '금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9702, test score : 0.1318
# ** rmse : 105.29908858775666
# XGBoost => train score : 0.9381, test score : 0.1452
# ** rmse : 104.4845711698959
# 독립변수 : Index(['무역수지', '금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9928, test score : 0.3487
# ** rmse : 91.1997217240516
# XGBoost => train score : 0.9885, test score : 0.3589
# ** rmse : 90.48322060630834
# 독립변수 : Index(['금속광물 수입금액', '철광석 수입금액', '무역수지'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9970, test score : 0.1482
# ** rmse : 104.29774508751777
# XGBoost => train score : 0.9936, test score : 0.1693
# ** rmse : 102.99913433204104
# 독립변수 : Index(['금속광물 수입금액', '철광석 수입금액', '철광석 가격'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9972, test score : 0.0282
# ** rmse : 111.40256443916445
# XGBoost => train score : 0.9960, test score : 0.0941
# ** rmse : 107.55926679905558
# 독립변수 : Index(['금속광물 수입금액', '무역수지', '철광석 가격'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9950, test score : 0.1149
# ** rmse : 106.31878533910572
# XGBoost => train score : 0.9965, test score : 0.3616
# ** rmse : 90.29557803552426
# 독립변수 : Index(['금속광물 수입금액', '무역수지', '금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9974, test score : 0.2789
# ** rmse : 95.9653600055232
# XGBoost => train score : 0.9970, test score : 0.2956
# ** rmse : 94.8501843928705
# 독립변수 : Index(['철광석 수입금액', '무역수지', '금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9986, test score : 0.0632
# ** rmse : 109.38024907235096
# XGBoost => train score : 0.9984, test score : 0.0459
# ** rmse : 110.38846855563398
# 독립변수 : Index(['금속광물 수입금액', '철광석 수입금액', '무역수지', '철광석 가격'], dtype='object')
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9974, test score : 0.1456
# ** rmse : 104.46040104453704
# XGBoost => train score : 0.9987, test score : 0.2762
# ** rmse : 96.14280790631926
# 독립변수 : Index(['금속광물 수입금액', '철광석 수입금액', '무역수지', '금(우축)'], dtype='object')
# ----------------------------------------------------------------------------------------------------

# %%
best_feature=['위안 환율', '금속광물 수입금액', '철광석 수입금액', '철광석 수입물량', '무역수지', '금(우축)']

# %%
# 스케일링 적용, 상관계수가 0.45 이상인 항목들 적용
import pandas as pd
from itertools import combinations

filename='best_r2_rf_xgb_result'

print('-'*100)
with open(f'./1204_1208/modeling_result/{filename}.txt', 'w') as file_data:
            file_data.write('-'*100+'\n')

# 조합을 이용하여 모든 경우의 수 계산
for cnt in range(1,len(best_index)+1):
    for i in combinations(best_index,cnt):
        feature=all_df[list(i)]
        target=all_df.iloc[:]['선반A (Turning Scrap A) 평균']
        # train, test 분리
        train_x=feature.iloc[:round(len(feature)*0.8),:]
        test_x=feature.iloc[round(len(feature)*0.8):,:]
        train_y=target.iloc[:round(len(feature)*0.8)]
        test_y=target.iloc[round(len(feature)*0.8):]
        # print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
        modeling_all(train_x, train_y, test_x, test_y, filename)

# %%
import pandas as pd
all_df = pd.read_csv('./data/tsa_all.csv')
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
for i in all_df.columns:
    if i!='날짜':
        all_df[i]=scaler.fit_transform(all_df[[i]])
print('-'*100)
# 독립변수, 종속변수 분리
feature = all_df[best_feature]
target = all_df['선반A (Turning Scrap A) 평균']
# train, test 분리
train_x=feature.iloc[:round(len(feature)*0.8),:]
test_x=feature.iloc[round(len(feature)*0.8):,:]
train_y=target.iloc[:round(len(feature)*0.8)]
test_y=target.iloc[round(len(feature)*0.8):]
# print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# RandomForest
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(train_x,train_y)
train_score_rf=model.score(train_x,train_y)
test_score_rf = model.score(test_x,test_y)
print(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}')
# XGBoost
from xgboost import XGBRegressor
model=XGBRegressor()
model.fit(train_x,train_y)
train_score_xgb = model.score(train_x,train_y)
test_score_xgb = model.score(test_x,test_y)
print(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}')
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9992, test score : -0.2106
# XGBoost => train score : 0.9993, test score : -0.1301
# ----------------------------------------------------------------------------------------------------

# %%
print('-'*100)
for cnt in range(1,len(best_feature)):
    # 조합을 이용하여 모든 경우의 수 계산
    for i in combinations(all_df[best_feature].columns,cnt):
        # 독립변수, 종속변수 분리
        feature = all_df[list(i)]
        target = all_df['선반A (Turning Scrap A) 평균']
        # train, test 분리
        train_x=feature.iloc[:round(len(feature)*0.8),:]
        test_x=feature.iloc[round(len(feature)*0.8):,:]
        train_y=target.iloc[:round(len(feature)*0.8)]
        test_y=target.iloc[round(len(feature)*0.8):]
        # print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
        # RandomForest
        from sklearn.ensemble import RandomForestRegressor
        model=RandomForestRegressor()
        model.fit(train_x,train_y)
        train_score_rf=model.score(train_x,train_y)
        test_score_rf = model.score(test_x,test_y)
        if test_score_rf > 0:
            print(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}')
        # XGBoost
        from xgboost import XGBRegressor
        model=XGBRegressor()
        model.fit(train_x,train_y)
        train_score_xgb = model.score(train_x,train_y)
        test_score_xgb = model.score(test_x,test_y)
        if test_score_xgb > 0:
            print(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}')
        if (test_score_rf > 0) or (test_score_xgb > 0):
            print(f'독립변수 : {list(i)}')
            print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8513, test score : 0.1431
# XGBoost => train score : 0.3392, test score : 0.2163
# 독립변수 : ['금속광물 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8599, test score : 0.0184
# XGBoost => train score : 0.3878, test score : 0.0509
# 독립변수 : ['금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9770, test score : 0.3028
# XGBoost => train score : 0.9437, test score : 0.3859
# 독립변수 : ['위안 환율', '금속광물 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9788, test score : 0.2309
# XGBoost => train score : 0.9533, test score : 0.1200
# 독립변수 : ['위안 환율', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9350, test score : 0.1159
# XGBoost => train score : 0.8355, test score : 0.1195
# 독립변수 : ['금속광물 수입금액', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9587, test score : 0.0693
# XGBoost => train score : 0.9065, test score : 0.1295
# 독립변수 : ['금속광물 수입금액', '철광석 수입물량']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9690, test score : 0.1156
# 독립변수 : ['금속광물 수입금액', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9798, test score : 0.1503
# XGBoost => train score : 0.9569, test score : 0.1241
# 독립변수 : ['금속광물 수입금액', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9704, test score : 0.1366
# XGBoost => train score : 0.9375, test score : 0.1543
# 독립변수 : ['무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9934, test score : 0.2457
# XGBoost => train score : 0.9877, test score : 0.3364
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입물량']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9955, test score : 0.2784
# XGBoost => train score : 0.9931, test score : 0.0302
# 독립변수 : ['위안 환율', '금속광물 수입금액', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9962, test score : 0.1919
# XGBoost => train score : 0.9944, test score : 0.2497
# 독립변수 : ['위안 환율', '금속광물 수입금액', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9945, test score : 0.1517
# 독립변수 : ['위안 환율', '철광석 수입물량', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9942, test score : 0.2866
# XGBoost => train score : 0.9946, test score : 0.3973
# 독립변수 : ['위안 환율', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9926, test score : 0.3348
# XGBoost => train score : 0.9879, test score : 0.3548
# 독립변수 : ['금속광물 수입금액', '철광석 수입금액', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9943, test score : 0.1345
# 독립변수 : ['금속광물 수입금액', '철광석 수입물량', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9951, test score : 0.2027
# XGBoost => train score : 0.9958, test score : 0.1928
# 독립변수 : ['금속광물 수입금액', '철광석 수입물량', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9952, test score : 0.0954
# XGBoost => train score : 0.9964, test score : 0.3628
# 독립변수 : ['금속광물 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9975, test score : 0.2760
# XGBoost => train score : 0.9972, test score : 0.2998
# 독립변수 : ['철광석 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# XGBoost => train score : 0.9974, test score : 0.1105
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입금액', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9984, test score : 0.0049
# XGBoost => train score : 0.9983, test score : 0.0889
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입금액', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9978, test score : 0.3062
# XGBoost => train score : 0.9976, test score : 0.1860
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입물량', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9982, test score : 0.2571
# XGBoost => train score : 0.9983, test score : 0.1465
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입물량', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9984, test score : 0.2530
# XGBoost => train score : 0.9988, test score : 0.3310
# 독립변수 : ['위안 환율', '금속광물 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# XGBoost => train score : 0.9990, test score : 0.1753
# 독립변수 : ['위안 환율', '철광석 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9969, test score : 0.2073
# XGBoost => train score : 0.9973, test score : 0.1951
# 독립변수 : ['위안 환율', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9961, test score : 0.2510
# 독립변수 : ['금속광물 수입금액', '철광석 수입금액', '철광석 수입물량', '무역수지']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9973, test score : 0.0351
# XGBoost => train score : 0.9985, test score : 0.2700
# 독립변수 : ['금속광물 수입금액', '철광석 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9976, test score : 0.2076
# XGBoost => train score : 0.9986, test score : 0.1143
# 독립변수 : ['금속광물 수입금액', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9985, test score : 0.2843
# XGBoost => train score : 0.9985, test score : 0.1266
# 독립변수 : ['철광석 수입금액', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9985, test score : 0.0196
# XGBoost => train score : 0.9986, test score : 0.0325
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입금액', '철광석 수입물량', '무역수지']
# ----------------------------------------------------------------------------------------------------
# XGBoost => train score : 0.9990, test score : 0.0866
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입금액', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9990, test score : 0.2519
# XGBoost => train score : 0.9991, test score : 0.2209
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# XGBoost => train score : 0.9991, test score : 0.1353
# 독립변수 : ['위안 환율', '철광석 수입금액', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9984, test score : 0.2211
# 독립변수 : ['금속광물 수입금액', '철광석 수입금액', '철광석 수입물량', '무역수지', '금(우축)']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# #### 항목별
# ---

# %%
shift_score = {}
for item in all_df.columns[2:]:
    shift_score[item]=[]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
for i in all_df.columns:
    if i!='날짜':
        all_df[i]=scaler.fit_transform(all_df[[i]])
for item in all_df.columns[2:]:
    result = []
    for i in range(0,71,7):
        feature = all_df[[item]].shift(i).dropna()
        target = all_df['선반A (Turning Scrap A) 평균'].iloc[i:]
        #-----------------------------------------------------------------------------------------------
        # train, test 분리
        train_x=feature.iloc[:round(len(feature)*0.8),:]
        test_x=feature.iloc[round(len(feature)*0.8):,:]
        train_y=target.iloc[:round(len(feature)*0.8)]
        test_y=target.iloc[round(len(feature)*0.8):]
        # print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
        #-----------------------------------------------------------------------------------------------
        # RandomForest
        from sklearn.ensemble import RandomForestRegressor
        model=RandomForestRegressor()
        model.fit(train_x,train_y)
        train_score_rf=model.score(train_x,train_y)
        test_score_rf = model.score(test_x,test_y)
        print(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}')
        #-----------------------------------------------------------------------------------------------
        # XGBoost
        from xgboost import XGBRegressor
        model=XGBRegressor()
        model.fit(train_x,train_y)
        train_score_xgb = model.score(train_x,train_y)
        test_score_xgb = model.score(test_x,test_y)
        print(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}')
        print(f'독립변수({i}일 shift) : {item}')
        result.append(test_score_xgb)
        print('-'*100)
        #-----------------------------------------------------------------------------------------------
    shift_score[item].append(result)
# Out:
# RandomForest => train score : 0.7140, test score : -2.1613
# XGBoost => train score : 0.4007, test score : -2.0450
# 독립변수(0일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7115, test score : -2.2259
# XGBoost => train score : 0.3967, test score : -2.0150
# 독립변수(7일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7093, test score : -2.2162
# XGBoost => train score : 0.4004, test score : -1.9817
# 독립변수(14일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7079, test score : -2.1675
# XGBoost => train score : 0.4034, test score : -1.9280
# 독립변수(21일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7058, test score : -2.1132
# XGBoost => train score : 0.4017, test score : -1.8549
# 독립변수(28일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7025, test score : -2.0647
# XGBoost => train score : 0.3960, test score : -1.7784
# 독립변수(35일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.6966, test score : -1.9420
# XGBoost => train score : 0.3883, test score : -1.7221
# 독립변수(42일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.6895, test score : -1.9145
# XGBoost => train score : 0.3821, test score : -1.7075
# 독립변수(49일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.6775, test score : -1.8822
# XGBoost => train score : 0.3729, test score : -1.6791
# 독립변수(56일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.6697, test score : -1.8409
# XGBoost => train score : 0.3516, test score : -1.6625
# 독립변수(63일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.6589, test score : -1.8280
# XGBoost => train score : 0.3351, test score : -1.6582
# 독립변수(70일 shift) : 달러 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8433, test score : -1.4952
# XGBoost => train score : 0.3392, test score : -1.1877
# 독립변수(0일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8420, test score : -1.4823
# XGBoost => train score : 0.3412, test score : -1.2055
# 독립변수(7일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8418, test score : -1.5145
# XGBoost => train score : 0.3415, test score : -1.2032
# 독립변수(14일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8449, test score : -1.5219
# XGBoost => train score : 0.3500, test score : -1.2124
# 독립변수(21일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8464, test score : -1.5239
# XGBoost => train score : 0.3581, test score : -1.2236
# 독립변수(28일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8471, test score : -1.5723
# XGBoost => train score : 0.3646, test score : -1.2419
# 독립변수(35일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8475, test score : -1.6078
# XGBoost => train score : 0.3716, test score : -1.2765
# 독립변수(42일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8483, test score : -1.7130
# XGBoost => train score : 0.3737, test score : -1.3312
# 독립변수(49일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8476, test score : -1.7693
# XGBoost => train score : 0.3762, test score : -1.3630
# 독립변수(56일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8469, test score : -1.8264
# XGBoost => train score : 0.3752, test score : -1.4263
# 독립변수(63일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8491, test score : -1.9106
# XGBoost => train score : 0.3766, test score : -1.5034
# 독립변수(70일 shift) : 엔 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8953, test score : -1.5541
# XGBoost => train score : 0.5477, test score : -1.5015
# 독립변수(0일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8945, test score : -1.5511
# XGBoost => train score : 0.5440, test score : -1.4857
# 독립변수(7일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8932, test score : -1.5605
# XGBoost => train score : 0.5389, test score : -1.5175
# 독립변수(14일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8923, test score : -1.5962
# XGBoost => train score : 0.5306, test score : -1.5378
# 독립변수(21일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8913, test score : -1.6303
# XGBoost => train score : 0.5176, test score : -1.5637
# 독립변수(28일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8879, test score : -1.6729
# XGBoost => train score : 0.5110, test score : -1.6038
# 독립변수(35일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8857, test score : -1.7026
# XGBoost => train score : 0.4999, test score : -1.6150
# 독립변수(42일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8829, test score : -1.7512
# XGBoost => train score : 0.4912, test score : -1.6293
# 독립변수(49일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8811, test score : -1.7821
# XGBoost => train score : 0.4810, test score : -1.6395
# 독립변수(56일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8762, test score : -1.7757
# XGBoost => train score : 0.4665, test score : -1.6594
# 독립변수(63일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8753, test score : -1.7949
# XGBoost => train score : 0.4554, test score : -1.6904
# 독립변수(70일 shift) : 유로 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7436, test score : -2.1371
# XGBoost => train score : 0.4328, test score : -1.9653
# 독립변수(0일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7430, test score : -2.1594
# XGBoost => train score : 0.4306, test score : -1.9215
# 독립변수(7일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7378, test score : -2.1459
# XGBoost => train score : 0.4198, test score : -1.8932
# 독립변수(14일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7339, test score : -2.0668
# XGBoost => train score : 0.4092, test score : -1.8223
# 독립변수(21일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7276, test score : -1.9533
# XGBoost => train score : 0.3944, test score : -1.7195
# 독립변수(28일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7211, test score : -1.8594
# XGBoost => train score : 0.3814, test score : -1.6477
# 독립변수(35일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7142, test score : -1.7709
# XGBoost => train score : 0.3750, test score : -1.5938
# 독립변수(42일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7102, test score : -1.7347
# XGBoost => train score : 0.3715, test score : -1.5702
# 독립변수(49일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7064, test score : -1.6724
# XGBoost => train score : 0.3651, test score : -1.5408
# 독립변수(56일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7064, test score : -1.6366
# XGBoost => train score : 0.3557, test score : -1.5096
# 독립변수(63일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7046, test score : -1.6213
# XGBoost => train score : 0.3491, test score : -1.4760
# 독립변수(70일 shift) : 위안 환율
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8531, test score : 0.1472
# XGBoost => train score : 0.3392, test score : 0.2163
# 독립변수(0일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8490, test score : 0.1604
# XGBoost => train score : 0.3329, test score : 0.2209
# 독립변수(7일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8503, test score : 0.1649
# XGBoost => train score : 0.3247, test score : 0.2197
# 독립변수(14일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8459, test score : 0.1664
# XGBoost => train score : 0.3149, test score : 0.2192
# 독립변수(21일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8422, test score : 0.1618
# XGBoost => train score : 0.3070, test score : 0.2144
# 독립변수(28일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8434, test score : 0.1557
# XGBoost => train score : 0.2986, test score : 0.2131
# 독립변수(35일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8401, test score : 0.1635
# XGBoost => train score : 0.2971, test score : 0.2155
# 독립변수(42일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8421, test score : 0.1721
# XGBoost => train score : 0.2930, test score : 0.2249
# 독립변수(49일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8411, test score : 0.1861
# XGBoost => train score : 0.2896, test score : 0.2392
# 독립변수(56일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8404, test score : 0.2041
# XGBoost => train score : 0.2903, test score : 0.2452
# 독립변수(63일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8400, test score : 0.2032
# XGBoost => train score : 0.2920, test score : 0.2401
# 독립변수(70일 shift) : 금속광물 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8497, test score : -0.3253
# XGBoost => train score : 0.3560, test score : -0.2997
# 독립변수(0일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8474, test score : -0.3245
# XGBoost => train score : 0.3541, test score : -0.2996
# 독립변수(7일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8464, test score : -0.3057
# XGBoost => train score : 0.3475, test score : -0.2897
# 독립변수(14일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8460, test score : -0.2981
# XGBoost => train score : 0.3423, test score : -0.2830
# 독립변수(21일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8466, test score : -0.2915
# XGBoost => train score : 0.3387, test score : -0.2778
# 독립변수(28일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8461, test score : -0.2883
# XGBoost => train score : 0.3350, test score : -0.2780
# 독립변수(35일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8414, test score : -0.2734
# XGBoost => train score : 0.3265, test score : -0.2646
# 독립변수(42일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8451, test score : -0.2692
# XGBoost => train score : 0.3214, test score : -0.2573
# 독립변수(49일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8452, test score : -0.2603
# XGBoost => train score : 0.3206, test score : -0.2528
# 독립변수(56일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8470, test score : -0.2496
# XGBoost => train score : 0.3236, test score : -0.2431
# 독립변수(63일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8479, test score : -0.2443
# XGBoost => train score : 0.3279, test score : -0.2402
# 독립변수(70일 shift) : 철광석 수입금액
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7793, test score : -1.5369
# XGBoost => train score : 0.0651, test score : -1.3818
# 독립변수(0일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7803, test score : -1.5519
# XGBoost => train score : 0.0652, test score : -1.3747
# 독립변수(7일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7828, test score : -1.5807
# XGBoost => train score : 0.0668, test score : -1.4039
# 독립변수(14일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7824, test score : -1.5991
# XGBoost => train score : 0.0681, test score : -1.4244
# 독립변수(21일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7904, test score : -1.6568
# XGBoost => train score : 0.0648, test score : -1.4508
# 독립변수(28일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7896, test score : -1.6893
# XGBoost => train score : 0.0708, test score : -1.4796
# 독립변수(35일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7919, test score : -1.6701
# XGBoost => train score : 0.0720, test score : -1.4640
# 독립변수(42일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7914, test score : -1.6420
# XGBoost => train score : 0.0742, test score : -1.4369
# 독립변수(49일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7907, test score : -1.5708
# XGBoost => train score : 0.0757, test score : -1.4112
# 독립변수(56일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7935, test score : -1.5394
# XGBoost => train score : 0.0796, test score : -1.3839
# 독립변수(63일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.7914, test score : -1.4921
# XGBoost => train score : 0.0785, test score : -1.3631
# 독립변수(70일 shift) : 금속광물 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8001, test score : -1.2115
# XGBoost => train score : 0.1545, test score : -0.8990
# 독립변수(0일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8041, test score : -1.1946
# XGBoost => train score : 0.1681, test score : -0.8822
# 독립변수(7일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8043, test score : -1.1922
# XGBoost => train score : 0.1769, test score : -0.8857
# 독립변수(14일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8076, test score : -1.2141
# XGBoost => train score : 0.1822, test score : -0.8790
# 독립변수(21일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8116, test score : -1.2348
# XGBoost => train score : 0.1927, test score : -0.8785
# 독립변수(28일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8114, test score : -1.2634
# XGBoost => train score : 0.1979, test score : -0.8925
# 독립변수(35일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8136, test score : -1.2719
# XGBoost => train score : 0.2051, test score : -0.9001
# 독립변수(42일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8137, test score : -1.3047
# XGBoost => train score : 0.2096, test score : -0.8997
# 독립변수(49일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8157, test score : -1.3081
# XGBoost => train score : 0.2150, test score : -0.9000
# 독립변수(56일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8174, test score : -1.3105
# XGBoost => train score : 0.2199, test score : -0.9105
# 독립변수(63일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8170, test score : -1.3111
# XGBoost => train score : 0.2197, test score : -0.9259
# 독립변수(70일 shift) : 철광석 수입물량
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8230, test score : -1.0421
# XGBoost => train score : 0.2320, test score : -0.4039
# 독립변수(0일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8246, test score : -1.0093
# XGBoost => train score : 0.2371, test score : -0.4232
# 독립변수(7일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8268, test score : -1.0114
# XGBoost => train score : 0.2424, test score : -0.4339
# 독립변수(14일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8260, test score : -0.9678
# XGBoost => train score : 0.2521, test score : -0.5003
# 독립변수(21일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8292, test score : -0.9822
# XGBoost => train score : 0.2672, test score : -0.5636
# 독립변수(28일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8341, test score : -0.9730
# XGBoost => train score : 0.2762, test score : -0.6478
# 독립변수(35일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8346, test score : -0.9309
# XGBoost => train score : 0.2807, test score : -0.6788
# 독립변수(42일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8343, test score : -0.8948
# XGBoost => train score : 0.2816, test score : -0.7184
# 독립변수(49일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8321, test score : -0.8572
# XGBoost => train score : 0.2809, test score : -0.7685
# 독립변수(56일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8338, test score : -0.9052
# XGBoost => train score : 0.2853, test score : -0.8117
# 독립변수(63일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8342, test score : -0.9189
# XGBoost => train score : 0.2882, test score : -0.8352
# 독립변수(70일 shift) : 무역수지
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9256, test score : -0.5279
# XGBoost => train score : 0.7039, test score : -0.4803
# 독립변수(0일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9190, test score : -0.5198
# XGBoost => train score : 0.6910, test score : -0.4736
# 독립변수(7일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9119, test score : -0.5188
# XGBoost => train score : 0.6766, test score : -0.4739
# 독립변수(14일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9041, test score : -0.5170
# XGBoost => train score : 0.6544, test score : -0.4732
# 독립변수(21일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8896, test score : -0.5302
# XGBoost => train score : 0.6214, test score : -0.4790
# 독립변수(28일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8742, test score : -0.5396
# XGBoost => train score : 0.5782, test score : -0.4955
# 독립변수(35일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8613, test score : -0.5464
# XGBoost => train score : 0.5372, test score : -0.5090
# 독립변수(42일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8504, test score : -0.5841
# XGBoost => train score : 0.4992, test score : -0.5389
# 독립변수(49일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8402, test score : -0.6127
# XGBoost => train score : 0.4662, test score : -0.5665
# 독립변수(56일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8290, test score : -0.6463
# XGBoost => train score : 0.4365, test score : -0.5913
# 독립변수(63일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8204, test score : -0.6625
# XGBoost => train score : 0.4133, test score : -0.6134
# 독립변수(70일 shift) : 철광석 가격
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8375, test score : -1.2122
# XGBoost => train score : 0.4100, test score : -1.1317
# 독립변수(0일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8395, test score : -1.1954
# XGBoost => train score : 0.4028, test score : -1.1416
# 독립변수(7일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8390, test score : -1.1842
# XGBoost => train score : 0.3976, test score : -1.0618
# 독립변수(14일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8405, test score : -1.1533
# XGBoost => train score : 0.3942, test score : -1.0328
# 독립변수(21일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8414, test score : -1.1200
# XGBoost => train score : 0.3906, test score : -1.0060
# 독립변수(28일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8437, test score : -1.0795
# XGBoost => train score : 0.3881, test score : -0.9627
# 독립변수(35일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8395, test score : -1.0389
# XGBoost => train score : 0.3793, test score : -0.8824
# 독립변수(42일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8381, test score : -0.9897
# XGBoost => train score : 0.3702, test score : -0.8498
# 독립변수(49일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8364, test score : -0.9249
# XGBoost => train score : 0.3658, test score : -0.7992
# 독립변수(56일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8350, test score : -0.8932
# XGBoost => train score : 0.3665, test score : -0.7714
# 독립변수(63일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8343, test score : -0.8576
# XGBoost => train score : 0.3638, test score : -0.7273
# 독립변수(70일 shift) : G20
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8377, test score : -1.3155
# XGBoost => train score : 0.4928, test score : -1.2713
# 독립변수(0일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8409, test score : -1.3201
# XGBoost => train score : 0.5024, test score : -1.2828
# 독립변수(7일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8489, test score : -1.3404
# XGBoost => train score : 0.5218, test score : -1.2942
# 독립변수(14일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8589, test score : -1.3382
# XGBoost => train score : 0.5442, test score : -1.3022
# 독립변수(21일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8688, test score : -1.3355
# XGBoost => train score : 0.5698, test score : -1.3052
# 독립변수(28일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8760, test score : -1.3428
# XGBoost => train score : 0.5944, test score : -1.3086
# 독립변수(35일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8855, test score : -1.3298
# XGBoost => train score : 0.6165, test score : -1.2991
# 독립변수(42일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8886, test score : -1.3299
# XGBoost => train score : 0.6251, test score : -1.2882
# 독립변수(49일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8893, test score : -1.3193
# XGBoost => train score : 0.6225, test score : -1.2689
# 독립변수(56일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8887, test score : -1.3032
# XGBoost => train score : 0.6130, test score : -1.2444
# 독립변수(63일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8860, test score : -1.2751
# XGBoost => train score : 0.5967, test score : -1.2207
# 독립변수(70일 shift) : 한국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8325, test score : -1.0797
# XGBoost => train score : 0.3099, test score : -0.9084
# 독립변수(0일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8326, test score : -1.0276
# XGBoost => train score : 0.3010, test score : -0.8675
# 독립변수(7일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8290, test score : -0.9812
# XGBoost => train score : 0.2959, test score : -0.8407
# 독립변수(14일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8252, test score : -0.9125
# XGBoost => train score : 0.2923, test score : -0.7851
# 독립변수(21일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8251, test score : -0.8487
# XGBoost => train score : 0.2851, test score : -0.7122
# 독립변수(28일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8204, test score : -0.7875
# XGBoost => train score : 0.2816, test score : -0.6653
# 독립변수(35일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8230, test score : -0.7398
# XGBoost => train score : 0.2810, test score : -0.6124
# 독립변수(42일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8206, test score : -0.6783
# XGBoost => train score : 0.2847, test score : -0.5730
# 독립변수(49일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8225, test score : -0.6452
# XGBoost => train score : 0.2874, test score : -0.5260
# 독립변수(56일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8221, test score : -0.5910
# XGBoost => train score : 0.2876, test score : -0.4704
# 독립변수(63일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8208, test score : -0.5136
# XGBoost => train score : 0.2947, test score : -0.4111
# 독립변수(70일 shift) : 미국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8261, test score : -1.1996
# XGBoost => train score : 0.3937, test score : -1.0880
# 독립변수(0일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8306, test score : -1.1814
# XGBoost => train score : 0.3934, test score : -1.0618
# 독립변수(7일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8324, test score : -1.1644
# XGBoost => train score : 0.3931, test score : -1.0470
# 독립변수(14일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8322, test score : -1.1408
# XGBoost => train score : 0.3967, test score : -1.0023
# 독립변수(21일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8331, test score : -1.1170
# XGBoost => train score : 0.3974, test score : -0.9707
# 독립변수(28일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8335, test score : -1.1021
# XGBoost => train score : 0.3894, test score : -0.9996
# 독립변수(35일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8322, test score : -1.0848
# XGBoost => train score : 0.3751, test score : -1.0121
# 독립변수(42일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8284, test score : -1.0984
# XGBoost => train score : 0.3664, test score : -0.9433
# 독립변수(49일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8256, test score : -1.0911
# XGBoost => train score : 0.3584, test score : -0.9733
# 독립변수(56일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8237, test score : -1.0741
# XGBoost => train score : 0.3492, test score : -1.0046
# 독립변수(63일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8220, test score : -1.0585
# XGBoost => train score : 0.3278, test score : -0.9601
# 독립변수(70일 shift) : 중국
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9063, test score : -0.6664
# XGBoost => train score : 0.5735, test score : -0.6432
# 독립변수(0일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9076, test score : -0.6829
# XGBoost => train score : 0.5746, test score : -0.6659
# 독립변수(7일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9085, test score : -0.7082
# XGBoost => train score : 0.5801, test score : -0.7022
# 독립변수(14일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9082, test score : -0.7436
# XGBoost => train score : 0.5824, test score : -0.7311
# 독립변수(21일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9083, test score : -0.7922
# XGBoost => train score : 0.5806, test score : -0.7371
# 독립변수(28일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9084, test score : -0.8659
# XGBoost => train score : 0.5800, test score : -0.7823
# 독립변수(35일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9074, test score : -0.8887
# XGBoost => train score : 0.5787, test score : -0.8211
# 독립변수(42일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9079, test score : -0.8917
# XGBoost => train score : 0.5854, test score : -0.8507
# 독립변수(49일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9113, test score : -0.9258
# XGBoost => train score : 0.5931, test score : -0.8575
# 독립변수(56일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9144, test score : -0.9371
# XGBoost => train score : 0.6027, test score : -0.8598
# 독립변수(63일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9175, test score : -0.9406
# XGBoost => train score : 0.6091, test score : -0.8480
# 독립변수(70일 shift) : 수입물가지수
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9399, test score : -0.7211
# XGBoost => train score : 0.7377, test score : -0.6785
# 독립변수(0일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9404, test score : -0.7620
# XGBoost => train score : 0.7405, test score : -0.7229
# 독립변수(7일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9410, test score : -0.8233
# XGBoost => train score : 0.7402, test score : -0.7696
# 독립변수(14일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9399, test score : -0.8490
# XGBoost => train score : 0.7348, test score : -0.7817
# 독립변수(21일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9366, test score : -0.8714
# XGBoost => train score : 0.7218, test score : -0.7918
# 독립변수(28일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9325, test score : -0.8963
# XGBoost => train score : 0.7068, test score : -0.8238
# 독립변수(35일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9288, test score : -0.9210
# XGBoost => train score : 0.6874, test score : -0.8505
# 독립변수(42일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9248, test score : -0.9765
# XGBoost => train score : 0.6665, test score : -0.8832
# 독립변수(49일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9183, test score : -0.9961
# XGBoost => train score : 0.6401, test score : -0.9099
# 독립변수(56일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9108, test score : -1.0058
# XGBoost => train score : 0.6104, test score : -0.9347
# 독립변수(63일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9035, test score : -1.0049
# XGBoost => train score : 0.5800, test score : -0.9476
# 독립변수(70일 shift) : 국제유가(Dubai, 좌축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8584, test score : 0.0193
# XGBoost => train score : 0.3878, test score : 0.0509
# 독립변수(0일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8620, test score : 0.0227
# XGBoost => train score : 0.3977, test score : 0.0428
# 독립변수(7일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8634, test score : -0.0045
# XGBoost => train score : 0.4056, test score : 0.0163
# 독립변수(14일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8666, test score : -0.0060
# XGBoost => train score : 0.4228, test score : 0.0054
# 독립변수(21일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8745, test score : 0.0010
# XGBoost => train score : 0.4431, test score : 0.0036
# 독립변수(28일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8786, test score : 0.0013
# XGBoost => train score : 0.4692, test score : -0.0041
# 독립변수(35일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8860, test score : -0.0118
# XGBoost => train score : 0.4900, test score : -0.0223
# 독립변수(42일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8909, test score : -0.0224
# XGBoost => train score : 0.5084, test score : -0.0359
# 독립변수(49일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8897, test score : -0.0244
# XGBoost => train score : 0.5055, test score : -0.0313
# 독립변수(56일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8876, test score : -0.0169
# XGBoost => train score : 0.4907, test score : -0.0136
# 독립변수(63일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.8867, test score : -0.0129
# XGBoost => train score : 0.4806, test score : -0.0051
# 독립변수(70일 shift) : 금(우축)
# ----------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt


cnt=0
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(20,20))
for item in shift_score.keys():
    cnt+=1
    plt.subplot(5,4,cnt)
    plt.plot(shift_score[item][0],label=item+' r2_score')
    plt.legend()
    # print(shift_score[item])

# %% [markdown]
# ---
# #### shift 시 개선되는 독립변수 이용하여 학습
# ---

# %%
best_feature = ['달러 환율', '위안 환율', '금속광물 수입금액', '철광석 수입금액','미국']
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from itertools import combinations
print('-'*100)
for cnt in range(2,len(best_feature)+1):
    # 조합을 이용하여 모든 경우의 수 계산
    for i in combinations(all_df[best_feature].columns,cnt):
        # 독립변수, 종속변수 분리
        feature = all_df[list(i)].shift(64).dropna()
        target = all_df['선반A (Turning Scrap A) 평균'].iloc[64:]
        # train, test 분리
        train_x=feature.iloc[:round(len(feature)*0.8),:]
        test_x=feature.iloc[round(len(feature)*0.8):,:]
        train_y=target.iloc[:round(len(feature)*0.8)]
        test_y=target.iloc[round(len(feature)*0.8):]
        # print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
        # RandomForest
        from sklearn.ensemble import RandomForestRegressor
        model=RandomForestRegressor()
        model.fit(train_x,train_y)
        train_score_rf=model.score(train_x,train_y)
        test_score_rf = model.score(test_x,test_y)
        if test_score_rf > 0:
            print(f'RandomForest => train score : {train_score_rf:.4f}, test score : {test_score_rf:.4f}')
        # XGBoost
        from xgboost import XGBRegressor
        model=XGBRegressor()
        model.fit(train_x,train_y)
        train_score_xgb = model.score(train_x,train_y)
        test_score_xgb = model.score(test_x,test_y)
        if test_score_xgb > 0:
            print(f'XGBoost => train score : {train_score_xgb:.4f}, test score : {test_score_xgb:.4f}')
        if (test_score_rf > 0) or (test_score_xgb > 0):
            print(f'독립변수 : {list(i)}')
            print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9652, test score : 0.2340
# 독립변수 : ['달러 환율', '금속광물 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9744, test score : 0.3291
# XGBoost => train score : 0.9426, test score : 0.3169
# 독립변수 : ['위안 환율', '금속광물 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9801, test score : 0.0070
# 독립변수 : ['위안 환율', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9900, test score : 0.2747
# XGBoost => train score : 0.9866, test score : 0.2074
# 독립변수 : ['달러 환율', '위안 환율', '금속광물 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9921, test score : 0.0463
# 독립변수 : ['달러 환율', '위안 환율', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9885, test score : 0.1122
# 독립변수 : ['달러 환율', '금속광물 수입금액', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9931, test score : 0.1574
# XGBoost => train score : 0.9895, test score : 0.0189
# 독립변수 : ['위안 환율', '금속광물 수입금액', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------
# RandomForest => train score : 0.9951, test score : 0.1797
# XGBoost => train score : 0.9958, test score : 0.0981
# 독립변수 : ['달러 환율', '위안 환율', '금속광물 수입금액', '철광석 수입금액']
# ----------------------------------------------------------------------------------------------------

# %%
# shift 적용 => R2스코어 하락
# 머신러닝이 아닌 시계열 및 딥러닝 모델로 접근 필요
# 문제점 : 데이터 수의 부족으로 인해 딥러닝으로 모델링이 가능할지 의문
